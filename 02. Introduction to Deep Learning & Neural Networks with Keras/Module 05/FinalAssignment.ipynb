# %% [markdown]
# ### A. Build a baseline model

# %% [markdown]
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error  as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the
# train_test_split
# helper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.
#
# Submit your Jupyter Notebook with your code and comments.

# %%
from keras.models import Sequential
from keras.layers import Input, Dense
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
concrete_data = pd.read_csv('https://cocl.us/concrete_data')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
X = concrete_data[[c for c in concrete_data.columns.to_list() if c != 'Strength']]
y = concrete_data[['Strength']]

# %%
def train(hidden_layers, epochs, X):
    mse_list = []
    for i in range(50):
        print(f'----------------------------Time {i}----------------------------')

        model = Sequential()
        model.add(Input((X.shape[1],)))
        for _ in range(hidden_layers):
            model.add(Dense(10, activation='relu'))
        model.add(Dense(1))

        model.compile(optimizer="adam", loss="mean_squared_error")
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=i)

        model.fit(X_train, y_train, epochs=epochs, verbose=0)

        predictions = model.predict(X_test)

        mse = mean_squared_error(y_test, predictions)
        mse_list.append(mse)
    return np.array(mse_list)

# %%
mse_list = train(1, 50, X)
print(f'Mse average: {mse_list.mean()}')
print(f'Mse standard deviation: {mse_list.std()}')
# Out:
# ----------------------------Time 0----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 1----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ----------------------------Time 2----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 3----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ----------------------------Time 4----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 5----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ----------------------------Time 6----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ----------------------------Time 7----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 8----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ...

# %% [markdown]
# ### B. Normalize the data (5 marks)
#
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# How does the mean of the mean squared errors compare to that from Step A?

# %%
X_normalized = (X - X.mean()) / X.std()

# %%
mse_list = train(1, 50, X_normalized)
print(f'Mse average: {mse_list.mean()}')
print(f'Mse standard deviation: {mse_list.std()}')
# Out:
# ----------------------------Time 0----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ----------------------------Time 1----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 2----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ----------------------------Time 3----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 4----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 5----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# ----------------------------Time 6----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ----------------------------Time 7----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# ----------------------------Time 8----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ...

# %%
print('Mse average is lower than it is in Step A')
# Out:
# Mse average is lower than it is in Step A

# %% [markdown]
# ### C. Increate the number of epochs (5 marks)
#
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
mse_list = train(1, 100, X_normalized)
print(f'Mse average: {mse_list.mean()}')
print(f'Mse standard deviation: {mse_list.std()}')
# Out:
# ----------------------------Time 0----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 1----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 2----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 3----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 4----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 5----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 6----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 7----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ----------------------------Time 8----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ...

# %%
print('Mse average is lower than it is in Step B')
# Out:
# Mse average is lower than it is in Step B

# %% [markdown]
# ### D. Increase the number of hidden layers (5 marks)
#
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
mse_list = train(3, 50, X_normalized)
print(f'Mse average: {mse_list.mean()}')
print(f'Mse standard deviation: {mse_list.std()}')
# Out:
# ----------------------------Time 0----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 1----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 2----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ----------------------------Time 3----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 4----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 5----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 6----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 7----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ----------------------------Time 8----------------------------
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ...

# %%
print('Mse average is lower than it is in Step C')
# Out:
# Mse average is lower than it is in Step C
